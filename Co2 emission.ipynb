# %%
import pandas as pd
import numpy as np
import seaborn as sb

# %%
df = pd.read_csv(r"C:\Users\Dell\Downloads\archive (4)\CO2 Emissions_Canada.csv")
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.drop(["Make","Model","Fuel Type","Vehicle Class","Fuel Consumption Comb (L/100 km)","Fuel Consumption Hwy (L/100 km)","Fuel Consumption Comb (mpg)","Transmission"],axis=1,inplace=True)

# %%
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       CO2 Emissions(g/km)
# 0                     196
# 1                     221
# 2                     136
# 3                     255
# 4                     244
# ...

# %%
lm = sb.lmplot(x="Engine Size(L)", y ="CO2 Emissions(g/km)", data=df,line_kws={'color':'black'})

# %%
x_bar=df["Engine Size(L)"].mean()
y_bar=df["CO2 Emissions(g/km)"].mean()
y_bar,x_bar
# Out:
# (np.float64(250.58469871360867), np.float64(3.160067704807041))

# %%
df["numertor"]=(df["Engine Size(L)"]-x_bar)*(df["CO2 Emissions(g/km)"]-y_bar)
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       CO2 Emissions(g/km)    numertor
# 0                     196   63.321946
# 1                     221   22.486374
# 2                     136  190.218358
# ...

# %%
df["denominator"]=(df["Engine Size(L)"])**2
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       CO2 Emissions(g/km)    numertor  denominator
# 0                     196   63.321946         4.00
# 1                     221   22.486374         5.76
# ...

# %%
theta1=df['numertor'].sum()/df['denominator'].sum()
theta1
# Out:
# np.float64(5.705144803216719)

# %%
theta0=y_bar=(theta1*x_bar)
theta0
# Out:
# np.float64(18.028643843892873)

# %%
f,(x="Engine Size(L)",y="CO2 Emission(g/km)",line_kws={'color':'black'})
# Out:
#   Cell In[38], line 1
#     f,(x="Engine Size(L)",y="CO2 Emission(g/km)",line_kws={'color':'black'})
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
